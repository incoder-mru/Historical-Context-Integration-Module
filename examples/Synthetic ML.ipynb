# %%
# !pip install torch
# !pip install torch_geometric
# !pip install matplotlib
# !pip install scipy
# !pip install scikit-learn
# Out:
# Requirement already satisfied: torch in /root/venv/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /root/venv/lib/python3.10/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /root/venv/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /root/venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /root/venv/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: sympy>=1.13.3 in /root/venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /root/venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: filelock in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch) (3.15.4)
# Requirement already satisfied: jinja2 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch) (3.0.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /root/venv/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /root/venv/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /root/venv/lib/python3.10/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /root/venv/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /root/venv/lib/python3.10/site-packages (from torch) (2.26.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch) (4.13.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /root/venv/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /root/venv/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /root/venv/lib/python3.10/site-packages (from torch) (3.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /root/venv/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: fsspec in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /root/venv/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: networkx in /root/venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: setuptools>=40.8.0 in /root/venv/lib/python3.10/site-packages (from triton==3.3.1->torch) (65.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /root/venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch_geometric in /root/venv/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: numpy in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: requests in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: fsspec in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: psutil>=5.8.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch_geometric) (6.0.0)
# Requirement already satisfied: aiohttp in /root/venv/lib/python3.10/site-packages (from torch_geometric) (3.12.13)
# Requirement already satisfied: jinja2 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from torch_geometric) (3.0.3)
# Requirement already satisfied: tqdm in /root/venv/lib/python3.10/site-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: pyparsing in /root/venv/lib/python3.10/site-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.6.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: propcache>=0.2.0 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: attrs>=17.3.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from aiohttp->torch_geometric) (24.2.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (5.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /root/venv/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: certifi>=2017.4.17 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->torch_geometric) (3.8)
# Requirement already satisfied: typing-extensions>=4.1.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp->torch_geometric) (4.13.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.23 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scipy in /root/venv/lib/python3.10/site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from scipy) (1.26.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: scipy>=1.8.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: numpy>=1.22.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from main import compare_approaches
results = compare_approaches(
    file_path="data/synthetic_er.csv.gz",
    epochs=25,  # Fewer epochs for faster testing
    num_time_bins=6,
    adaptive_weights=True,
    base_weights=0.3,
    verbose=True,
    title="Synthetic ER ML Demo"
)
# Out:
# Using GPU: Tesla T4
# ======================================================================
# SE-SGFORMER: HISTORICAL CONTEXT vs BASELINE COMPARISON
# ======================================================================
# Loading dataset: data/synthetic_er.csv.gz
# Raw data: 306563 edges
# Time range: 1000000000 to 1000604800
# Timestep 1: 127012 edges (107426+, 19586-)
# Timestep 2: 18033 edges (15134+, 2899-)
# Timestep 3: 15748 edges (13266+, 2482-)
# Timestep 4: 48002 edges (40605+, 7397-)
# Timestep 5: 21450 edges (18180+, 3270-)
# Timestep 6: 76318 edges (64468+, 11850-)
#
#  Experiment Setup:
#    Target timestep: 6 (76318 edges)
#    Historical timesteps: 5
#    Total nodes: 5000
#    Epochs: 25
#    Model dimensions: 128
#    Use adaptive weights: False
#
#  Training Baseline Model...
# --------------------------------------------------
#    Epoch 0: Loss = 264.6325
#    Epoch 10: Loss = 51.5279
#    Epoch 20: Loss = 19.3988
#    Epoch 24: Loss = 14.2582
#    Test edges: 76318, Labels: 64468 pos, 11850 neg
#    Score range: 14.4302 to 43.6974
#    P@100: 0.7600 (76/100 correct)
# Baseline Results: AUC = 0.5630, F1 = 0.6427, P@100 = 0.7600
#
#  Training Temporal Model...
# --------------------------------------------------
#    Extracting context from 5 previous timesteps...
#    Epoch 0: Loss = 132.2295
#    Epoch 10: Loss = 26.3982
#    Epoch 20: Loss = 9.5948
#    Epoch 24: Loss = 7.1285
#    Test edges: 76318, Labels: 64468 pos, 11850 neg
#    Score range: 1.4267 to 17.5100
#    P@100: 0.9200 (92/100 correct)
# Temporal Results: AUC = 0.5608, F1 = 0.7285, P@100 = 0.9200
#
#  FINAL COMPARISON
# ==================================================
# AUC:       0.5630 → 0.5608 (-0.0022, -0.4%)
# F1:        0.6427 → 0.7285 (+0.0858, +13.4%)
# P@100:     0.7600 → 0.9200 (+0.1600, +21.1%)
#
#  Generating Visualizations...
# Warning: Could not save results: [Errno 2] No such file or directory: 'results/comparison_results.json'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8755ff0a-cc68-4cd0-af0f-685fcbf308f2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
