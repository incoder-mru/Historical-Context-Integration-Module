# %%
from heuristics import test_signed_heuristics
results = test_signed_heuristics('data/synthetic_er.csv.gz',
                                target_timestep=3,
                                num_time_bins=6,
                                title="Synthetic ER Heuristic Demo")
# Out:
# ================================================================================
# SIGNED NETWORK HEURISTICS
# ================================================================================
# Loading dataset: data/synthetic_er.csv.gz
# Raw data: 306563 edges
# Time range: 1000000000 to 1000604800
# Timestep 1: 127012 edges (107426+, 19586-)
# Timestep 2: 18033 edges (15134+, 2899-)
# Timestep 3: 15748 edges (13266+, 2482-)
# Timestep 4: 48002 edges (40605+, 7397-)
# Timestep 5: 21450 edges (18180+, 3270-)
# Timestep 6: 76318 edges (64468+, 11850-)
#
# Test setup:
#   Target timestep: 4
#   Positive edges: 40605
#   Negative edges: 7397
#   Total edges: 48002
#   Total nodes: 5000
#   Test edges: 48002
#
# ============================================================
# Majority Class Prediction
# ============================================================
# Majority Class: AUC = 0.4961, F1 = 0.9165
#   Precision@100 = 0.8600
#
# ============================================================
# Signed Preferential Attachment
# ============================================================
# Signed Preferential Attachment: AUC = 0.5994, F1 = 0.6481
#   Precision@100 = 0.9500
#
# ============================================================
# Positive Common Neighbors (Signed-Aware)
# ============================================================
# Positive Common Neighbors: AUC = 0.4992, F1 = 0.0967
#   Precision@100 = 0.9200
#
# ============================================================
# Signed Status Theory
# ============================================================
# Signed Status Theory: AUC = 0.5058, F1 = 0.5710
#   Precision@100 = 1.0000
#
# ============================================================
# Signed Jaccard Similarity
# ============================================================
# Signed Jaccard Similarity: AUC = 0.4989, F1 = 0.0967
#   Precision@100 = 0.8100
#
# ============================================================
# Signed Adamic-Adar Index
# ============================================================
# Signed Adamic-Adar Index: AUC = 0.4991, F1 = 0.0967
#   Precision@100 = 0.8900
#
# ============================================================
# Signed Clustering Coefficient
# ============================================================
# Signed Clustering Coefficient: AUC = 0.5213, F1 = 0.6326
#   Precision@100 = 1.0000
#
# ============================================================
# Signed 2-Hop Paths
# ============================================================
# Signed 2-Hop Paths: AUC = 0.5002, F1 = 0.0982
#   Precision@100 = 0.9200
#
# ============================================================
# SIGNED NETWORK HEURISTICS COMPARISON RESULTS
# ============================================================
# Rank Heuristic                      Type            AUC      F1
# ----------------------------------------------------------------------
# 1    signed_preferential_attachment signed_specific 0.5994   0.6481
# 2    signed_clustering_coefficient  signed_specific 0.5213   0.6326
# 3    signed_status_theory           signed_specific 0.5058   0.5710
# 4    signed_2hop_paths              signed_specific 0.5002   0.0982
# 5    positive_common_neighbors      signed_aware    0.4992   0.0967
# 6    signed_adamic_adar             signed_aware    0.4991   0.0967
# 7    signed_jaccard_similarity      signed_aware    0.4989   0.0967
# 8    majority_class                 baseline        0.4961   0.9165
#
#  Best performing heuristic: signed_preferential_attachment
#    Type: signed_specific
#    AUC: 0.5994, F1: 0.6481
#
#  Performance by Type:
#    baseline       : Avg AUC = 0.4961, Avg F1 = 0.9165 (1 heuristics)
#    signed_aware   : Avg AUC = 0.4991, Avg F1 = 0.0967 (3 heuristics)
#    signed_specific: Avg AUC = 0.5317, Avg F1 = 0.4874 (4 heuristics)
#
# ============================================================
# SIGNED NETWORK HEURISTICS PERFORMANCE VISUALIZATION
# ============================================================
# Signed AUC scores plot saved: signed_heuristics_auc_t4.png
# Signed F1 scores plot saved: signed_heuristics_f1_t4.png
# Signed Precision@K bar charts saved: signed_heuristics_precision_bars_t4.png

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8755ff0a-cc68-4cd0-af0f-685fcbf308f2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
