# %%
from heuristics import test_signed_heuristics
results = test_signed_heuristics('data/soc-sign-bitcoinotc.csv.gz',
                                target_timestep=3,
                                num_time_bins=6,
                                title="Bitcoin OTC Heuristic Demo")
# Out:
# ================================================================================
# SIGNED NETWORK HEURISTICS
# ================================================================================
# Loading dataset: data/soc-sign-bitcoinotc.csv.gz
# Raw data: 35592 edges
# Time range: 1289241911.72836 to 1453684323.75728
# Timestep 1: 6871 edges (6728+, 143-)
# Timestep 2: 5399 edges (5227+, 172-)
# Timestep 3: 11616 edges (10435+, 1181-)
# Timestep 4: 8285 edges (6657+, 1628-)
# Timestep 5: 2676 edges (2284+, 392-)
# Timestep 6: 745 edges (698+, 47-)
#
# Test setup:
#   Target timestep: 4
#   Positive edges: 6657
#   Negative edges: 1628
#   Total edges: 8285
#   Total nodes: 5881
#   Test edges: 8285
#
# ============================================================
# Majority Class Prediction
# ============================================================
# Majority Class: AUC = 0.5039, F1 = 0.8910
#   Precision@100 = 0.8100
#
# ============================================================
# Signed Preferential Attachment
# ============================================================
# Signed Preferential Attachment: AUC = 0.8052, F1 = 0.7044
#   Precision@100 = 0.9900
#
# ============================================================
# Positive Common Neighbors (Signed-Aware)
# ============================================================
# Positive Common Neighbors: AUC = 0.7299, F1 = 0.7049
#   Precision@100 = 0.9700
#
# ============================================================
# Signed Status Theory
# ============================================================
# Signed Status Theory: AUC = 0.4704, F1 = 0.5933
#   Precision@100 = 1.0000
#
# ============================================================
# Signed Jaccard Similarity
# ============================================================
# Signed Jaccard Similarity: AUC = 0.7291, F1 = 0.7049
#   Precision@100 = 1.0000
#
# ============================================================
# Signed Adamic-Adar Index
# ============================================================
# Signed Adamic-Adar Index: AUC = 0.7305, F1 = 0.7049
#   Precision@100 = 0.9800
#
# ============================================================
# Signed Clustering Coefficient
# ============================================================
# Signed Clustering Coefficient: AUC = 0.4624, F1 = 0.6073
#   Precision@100 = 1.0000
#
# ============================================================
# Signed 2-Hop Paths
# ============================================================
# Signed 2-Hop Paths: AUC = 0.7337, F1 = 0.6956
#   Precision@100 = 0.9900
#
# ============================================================
# SIGNED NETWORK HEURISTICS COMPARISON RESULTS
# ============================================================
# Rank Heuristic                      Type            AUC      F1
# ----------------------------------------------------------------------
# 1    signed_preferential_attachment signed_specific 0.8052   0.7044
# 2    signed_2hop_paths              signed_specific 0.7337   0.6956
# 3    signed_adamic_adar             signed_aware    0.7305   0.7049
# 4    positive_common_neighbors      signed_aware    0.7299   0.7049
# 5    signed_jaccard_similarity      signed_aware    0.7291   0.7049
# 6    majority_class                 baseline        0.5039   0.8910
# 7    signed_status_theory           signed_specific 0.4704   0.5933
# 8    signed_clustering_coefficient  signed_specific 0.4624   0.6073
#
#  Best performing heuristic: signed_preferential_attachment
#    Type: signed_specific
#    AUC: 0.8052, F1: 0.7044
#
#  Performance by Type:
#    baseline       : Avg AUC = 0.5039, Avg F1 = 0.8910 (1 heuristics)
#    signed_aware   : Avg AUC = 0.7298, Avg F1 = 0.7049 (3 heuristics)
#    signed_specific: Avg AUC = 0.6179, Avg F1 = 0.6502 (4 heuristics)
#
# ============================================================
# SIGNED NETWORK HEURISTICS PERFORMANCE VISUALIZATION
# ============================================================
# Signed AUC scores plot saved: signed_heuristics_auc_t4.png
# Signed F1 scores plot saved: signed_heuristics_f1_t4.png
# Signed Precision@K bar charts saved: signed_heuristics_precision_bars_t4.png

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8755ff0a-cc68-4cd0-af0f-685fcbf308f2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
