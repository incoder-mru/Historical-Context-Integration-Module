# %%
# !pip install torch
# !pip install torch_geometric
# !pip install matplotlib
# !pip install scipy
# !pip install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 108.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 124.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 18.4 MB/s eta 0:00:00
# ...

# %%
from main import compare_approaches
results = compare_approaches(
    file_path="data/soc-sign-bitcoinotc.csv.gz",
    epochs=25,  # Fewer epochs for faster testing
    num_time_bins=6,
    adaptive_weights=True,
    base_weights=0.3,
    verbose=True,
    title="Bitcoin OTC ML Demo"
)
# Out:
# Using GPU: Tesla T4
# ...
# SE-SGFORMER: HISTORICAL CONTEXT vs BASELINE COMPARISON
# ...
# Loading dataset: data/soc-sign-bitcoinotc.csv.gz
# Raw data: 35592 edges
# Time range: 1289241911.72836 to 1453684323.75728
# Timestep 1: 6871 edges (6728+, 143-)
# Timestep 2: 5399 edges (5227+, 172-)
# Timestep 3: 11616 edges (10435+, 1181-)
# Timestep 4: 8285 edges (6657+, 1628-)
# Timestep 5: 2676 edges (2284+, 392-)
# Timestep 6: 745 edges (698+, 47-)
#
#  Experiment Setup:
#    Target timestep: 6 (745 edges)
#    Historical timesteps: 5
#    Total nodes: 5881
#    Epochs: 25
#    Model dimensions: 128
#    Use adaptive weights: False
#
#  Training Baseline Model...
# --------------------------------------------------
#    Epoch 0: Loss = 191.8972
#    Epoch 10: Loss = 14.8628
#    Epoch 20: Loss = 21.9288
#    Epoch 24: Loss = 11.9022
#    Test edges: 745, Labels: 698 pos, 47 neg
#    Score range: -7.7269 to 146.6838
#    P@100: 0.9000 (90/100 correct)
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8755ff0a-cc68-4cd0-af0f-685fcbf308f2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
